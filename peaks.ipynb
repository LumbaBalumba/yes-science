# %%
import numpy as np

# %%
samples = np.load('samples.npy')

# %%
import matplotlib.pyplot as plt

# %%
for t, X in samples:
    plt.plot(t, X)
    peaks = find_smooth_peaks(X)
    n_peaks.append(len(peaks))
    plt.vlines(t[peaks], color='red', ymin=0, ymax=2000)
    plt.show()

# %%
plt.hist(n_peaks, bins=10)
# Out:
# (array([ 8.,  0., 32.,  0.,  0., 12.,  0.,  7.,  0.,  1.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)
